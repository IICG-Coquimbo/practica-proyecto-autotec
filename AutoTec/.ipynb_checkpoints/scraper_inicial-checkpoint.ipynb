# %%
import requests 
from bs4 import BeautifulSoup 
# Configuraci n de entrada 
url = "https://www.chileautos.cl/" 
headers = {"User-Agent": "Mozilla/5.0"} # Para que no nos bloqueen 
# 1. Petici n al servidor 
respuesta = requests.get(url, headers=headers) 
# 2. Convertir el HTML en un objeto de Python 
sopa = BeautifulSoup(respuesta.text, "html.parser") 
# 3. Buscar los datos (Ejemplo: buscar todos los t tulos) # Cambia ’h2’ y ’nombre-de-la-clase’ por lo que inspeccionaste resultados = sopa.find_all(’h2’, class_=’nombre-de-la-clase’) 
# 4. Mostrar en pantalla 
for dato in resultados: 
    print(f"Encontrado: {dato.text.strip()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 12
#       9 sopa = BeautifulSoup(respuesta.text, "html.parser")
#      10 # 3. Buscar los datos (Ejemplo: buscar todos los t tulos) # Cambia ’h2’ y ’nombre-de-la-clase’ por lo que inspeccionaste resultados = sopa.find_all(’h2’, class_=’nombre-de-la-clase’)
#      11 # 4. Mostrar en pantalla
# ---> 12 for dato in resultados:
#      13     print(f"Encontrado: {dato.text.strip()}")
#
# NameError: name 'resultados' is not defined
