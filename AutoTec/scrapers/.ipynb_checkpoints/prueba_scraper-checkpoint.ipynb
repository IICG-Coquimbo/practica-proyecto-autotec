# %%
import sys
import importlib

sys.path.append("/home/jovyan/work/AutoTec/scrapers")

import scraper_jocelyn
importlib.reload(scraper_jocelyn)

datos = scrapers.ejecutar_extraccion(max_autos=5)

print("Total:", len(datos))
print(datos[:1])
# Out:
# Procesando marca: hyundai
# Elementos detectados (sin filtrar): 123
# Autos válidos en esta marca: 18
# Total autos válidos acumulados: 18
#
# Procesando marca: chevrolet
# Elementos detectados (sin filtrar): 123
# Autos válidos en esta marca: 20
# Total autos válidos acumulados: 38
#
# Procesando marca: toyota
# Elementos detectados (sin filtrar): 123
# Autos válidos en esta marca: 13
# Total autos válidos acumulados: 51
#
# Procesando marca: kia
# Elementos detectados (sin filtrar): 123
# Autos válidos en esta marca: 10
# Total autos válidos acumulados: 61
#
# Procesando marca: nissan
# Elementos detectados (sin filtrar): 122
# Autos válidos en esta marca: 20
# Total autos válidos acumulados: 81
#
# Procesando marca: mazda
# Elementos detectados (sin filtrar): 123
# Autos válidos en esta marca: 20
# Total autos válidos acumulados: 101
#
# Procesando marca: suzuki
# Elementos detectados (sin filtrar): 122
# Autos válidos en esta marca: 19
# Total autos válidos acumulados: 120
#
# ...
