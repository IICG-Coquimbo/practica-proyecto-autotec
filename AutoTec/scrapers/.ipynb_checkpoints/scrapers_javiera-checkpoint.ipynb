# %%
import sys
import importlib

sys.path.append("/home/jovyan/work/autotec")

import scrapers
importlib.reload(scrapers)

datos = scrapers.ejecutar_extraccion(max_paginas=50)

print("Total extraído:", len(datos))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 9
#       6 import scrapers
#       7 importlib.reload(scrapers)
# ----> 9 datos = scrapers.ejecutar_extraccion(max_paginas=50)
#      11 print("Total extraído:", len(datos))
#
# File ~/work/autotec/scrapers/scraper_javiera.py:28, in ejecutar_extraccion(max_paginas)
#      26 url = f"https://www.clicar.cl/vehiculos/usado?page={pagina}"
#      27 driver.get(url)
# ---> 28 time.sleep(5)
#      30 autos = driver.find_elements(By.CSS_SELECTOR, "li.h-fit")
#      32 for auto in autos:
#
# KeyboardInterrupt:
