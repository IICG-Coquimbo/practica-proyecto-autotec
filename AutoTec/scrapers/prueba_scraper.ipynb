# %%
import sys
import importlib

sys.path.append("/home/jovyan/work/AutoTec/scrapers")

import scraper_jocelyn
importlib.reload(scraper_jocelyn)

datos = scraper_jocelyn.ejecutar_extraccion(max_autos=500)

print("Total:", len(datos))
# Out:
# Limpieza lista.
#
# Total capturado en esta ejecución: 0
#
# Iniciando extracción de links...
#
# Buscando links en marca: hyundai
# https://autos.cari.cl/autos/hyundai
# Links encontrados en marca: 5
# Total links acumulados: 5
#
# Total de links obtenidos: 5
#
# Iniciando extracción de detalles...
# Capturado 1/5 | Link revisado 1/5
# Capturado 2/5 | Link revisado 2/5
# Capturado 3/5 | Link revisado 3/5
# Capturado 4/5 | Link revisado 4/5
# Capturado 5/5 | Link revisado 5/5
#
# Extracción terminada.
# Total autos capturados: 5
# Total: 5
