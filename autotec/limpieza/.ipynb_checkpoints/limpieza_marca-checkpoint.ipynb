# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lower, trim, when, translate

spark = SparkSession.builder \
    .appName("EDA_AutoTec_Marca") \
    .config(
        "spark.jars.packages",
        "org.mongodb.spark:mongo-spark-connector_2.12:3.0.1"
    ) \
    .getOrCreate()

df_raw = spark.read.format("mongo") \
    .option(
        "uri",
        "mongodb+srv://neiel_cortes:neiel0330@cluster0.eo0kyfv.mongodb.net/proyecto_bigdata.lista_autos"
    ) \
    .load()

df_raw.show(5)
# Out:
# +--------------------+---------+-----------+-------------------+------+-------+-----------+------+-------+--------+--------------------+-------+----+
# |                 _id|   ciudad|combustible|      fecha_captura|fuente|  grupo|kilometraje| marca| modelo|  precio|                 url|usuario|year|
# +--------------------+---------+-----------+-------------------+------+-------+-----------+------+-------+--------+--------------------+-------+----+
# |{69f3e873b71b4c57...|     buin|     diesel|2026-04-30 23:39:11|  NULL|autotec|     180 km|toyota|  hilux|12600000|https://www.yapo....|   dani|2018|
# |{69f3e873b71b4c57...|cerrillos|    bencina|2026-04-30 23:39:11|  NULL|autotec|  112000 km| honda|   wr-v| 9280000|https://www.yapo....|   dani|2021|
# |{69f3e873b71b4c57...|cerrillos|    bencina|2026-04-30 23:39:12|  NULL|autotec|   20789 km|   kia|morning| 9680000|https://www.yapo....|   dani|2023|
# |{69f3e873b71b4c57...|  quilpué|     diesel|2026-04-30 23:39:12|  NULL|autotec|  108000 km|nissan| navara|19000000|https://www.yapo....|   dani|2021|
# |{69f3e873b71b4c57...|   molina|    bencina|2026-04-30 23:39:12|  NULL|autotec|  161900 km|nissan|  kicks| 9000000|https://www.yapo....|   dani|2021|
# +--------------------+---------+-----------+-------------------+------+-------+-----------+------+-------+--------+--------------------+-------+----+
# only showing top 5 rows

# %%
from pyspark.sql.functions import *

# %%
marca = lower(trim(col("marca")))

# quitar tildes
marca = translate(
    marca,
    "áéíóúüñ",
    "aeiouun"
)

# extraer solo primera palabra
marca = split(marca, " ").getItem(0)

df_limpio = df_raw.withColumn("marca_limpia", marca)

# %%
df_limpio = df_limpio.withColumn(
    "marca_limpia",

    when(col("marca_limpia").isin("chevy"), "chevrolet")
    .when(col("marca_limpia").isin("mercedes-benz"), "mercedes")
    .when(col("marca_limpia").isin("vw"), "volkswagen")

    # Great Wall
    .when(col("marca_limpia") == "great-wall", "great wall")

    # Renault Samsung
    .when(col("marca_limpia") == "renault-samsung", "renault")

    # Land Rover
    .when(col("marca_limpia") == "range", "land rover")

    # SsangYong
    .when(col("marca_limpia").isin(
        "actyon",
        "korando",
        "rexton"
    ), "ssangyong")

    # Mini
    .when(col("marca_limpia") == "cooper", "mini")

    # Kia
    .when(col("marca_limpia") == "rio", "kia")

    # MG
    .when(col("marca_limpia").isin(
        "zs",
        "hs"
    ), "mg")

    # Eliminar basura
    .when(col("marca_limpia").isin(
        "3",
        "4x4",
        "ano",
        "automatico",
        "diesel",
        "full",
        "garantizado",
        "grand",
        "gt",
        "imperdibles",
        "jim",
        "mantencion",
        "mantenciones",
        "rebajado",
        "usado",
        "valor",
        "zx",
        "c5"
    ), None)

    .otherwise(col("marca_limpia"))
)

# %%
marcas_invalidas = [
    "",
    "null",
    "nan",
    "poco",
    "semi",
    "usados",
    "vendo",
    "unico",
    "recien",
    "bajo",
    "cotiza",
    "descuenta",
    "2"
]

df_limpio = df_limpio.filter(
    (~col("marca_limpia").isin(marcas_invalidas)) &
    col("marca_limpia").isNotNull()
)

# %%
df_limpio.select("marca_limpia") \
         .distinct() \
         .orderBy("marca_limpia") \
         .show(200, False)
# Out:
# +--------------------------+
# |marca_limpia              |
# +--------------------------+
# |audi                      |
# |baic                      |
# |bmw                       |
# |brilliance                |
# |byd                       |
# |changan                   |
# |chery                     |
# |chevrolet                 |
# |citroen                   |
# |citroën                   |
# |cupra                     |
# |daewoo                    |
# |daihatsu                  |
# |dfm                       |
# |dfsk                      |
# |dodge                     |
# |dongfeng                  |
# |ds                        |
# |ducati                    |
# |exeed                     |
# |faw                       |
# |fiat                      |
# |ford                      |
# |foton                     |
# |gac                       |
# |geely                     |
# |great                     |
# |great wall                |
# |haval                     |
# |honda                     |
# |hyundai                   |
# |infiniti                  |
# |international             |
# |jac                       |
# |jaecoo                    |
# |jaguar                    |
# |jeep                      |
# |jetour                    |
# |jim-(jiangxi-isuzu-motors)|
# |jmc                       |
# |kaiyi                     |
# |karry                     |
# |kia                       |
# |kyc                       |
# |land                      |
# |land rover                |
# |land-rover                |
# |lexus                     |
# |lifan                     |
# |mahindra                  |
# |maxus                     |
# |mazda                     |
# |mercedes                  |
# |mg                        |
# |mini                      |
# |mitsubishi                |
# |nissan                    |
# |omoda                     |
# |opel                      |
# |peugeot                   |
# |porsche                   |
# |ram                       |
# |renault                   |
# |seat                      |
# |shineray                  |
# |skoda                     |
# |ssangyong                 |
# |subaru                    |
# |suzuki                    |
# |swm                       |
# |tata                      |
# |tesla                     |
# |toyota                    |
# |uaz                       |
# |volkswagen                |
# |volvo                     |
# |zna                       |
# +--------------------------+

# %%
df_limpio = df_limpio.withColumn(
    "marca_limpia",

    when(col("marca_limpia") == "great", "great wall")
    .when(col("marca_limpia") == "land", "land rover")
    .when(col("marca_limpia") == "citroën", "citroen")
    .otherwise(col("marca_limpia"))
)

# %%
from pyspark.sql.functions import when, col

df_limpio = df_limpio.withColumn(
    "marca_limpia",
    when(
        col("marca_limpia").isin(
            "international",
            "jim-(jiangxi-isuzu-motors)",
            "kyc",
            "zna",
            "ducati"
        ),
        "otros"
    ).otherwise(col("marca_limpia"))
)

# %%
df_limpio = df_limpio.withColumn(
    "marca_limpia",

    when(col("marca_limpia") == "land-rover", "land rover")
    .otherwise(col("marca_limpia"))
)

# %%
df_limpio.groupBy("marca_limpia") \
    .count() \
    .orderBy(col("count").desc()) \
    .show(50, False)
# Out:
# +------------+-----+
# |marca_limpia|count|
# +------------+-----+
# |chevrolet   |290  |
# |ford        |271  |
# |peugeot     |255  |
# |nissan      |245  |
# |chery       |172  |
# |toyota      |167  |
# |kia         |137  |
# |hyundai     |134  |
# |mg          |119  |
# |volkswagen  |112  |
# |mazda       |99   |
# |suzuki      |72   |
# |ssangyong   |67   |
# |jeep        |65   |
# |subaru      |62   |
# |mitsubishi  |61   |
# |mercedes    |55   |
# |audi        |55   |
# |changan     |55   |
# |citroen     |53   |
# |haval       |48   |
# |jaecoo      |45   |
# |great wall  |43   |
# |bmw         |43   |
# |opel        |43   |
# |ram         |42   |
# |honda       |42   |
# |renault     |42   |
# |maxus       |40   |
# |jac         |36   |
# |dfsk        |32   |
# |volvo       |31   |
# |omoda       |29   |
# |gac         |26   |
# |land rover  |25   |
# |dodge       |23   |
# |jetour      |20   |
# |fiat        |20   |
# |geely       |17   |
# |skoda       |15   |
# |jmc         |14   |
# |mini        |13   |
# |jaguar      |12   |
# |lexus       |11   |
# |baic        |10   |
# |exeed       |10   |
# |foton       |10   |
# |cupra       |8    |
# |mahindra    |7    |
# |porsche     |7    |
# +------------+-----+
# only showing top 50 rows

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import dense_rank

window_spec = Window.orderBy("marca_limpia")

df_limpio = df_limpio.withColumn(
    "cat_marcas",
    dense_rank().over(window_spec)
)

# %%
df_limpio.select(
    "marca_limpia",
    "cat_marcas"
).distinct().orderBy("cat_marcas").show(100, False)
# Out:
# +------------+----------+
# |marca_limpia|cat_marcas|
# +------------+----------+
# |audi        |1         |
# |baic        |2         |
# |bmw         |3         |
# |brilliance  |4         |
# |byd         |5         |
# |changan     |6         |
# |chery       |7         |
# |chevrolet   |8         |
# |citroen     |9         |
# |cupra       |10        |
# |daewoo      |11        |
# |daihatsu    |12        |
# |dfm         |13        |
# |dfsk        |14        |
# |dodge       |15        |
# |dongfeng    |16        |
# |ds          |17        |
# |exeed       |18        |
# |faw         |19        |
# |fiat        |20        |
# |ford        |21        |
# |foton       |22        |
# |gac         |23        |
# |geely       |24        |
# |great wall  |25        |
# |haval       |26        |
# |honda       |27        |
# |hyundai     |28        |
# |infiniti    |29        |
# |jac         |30        |
# |jaecoo      |31        |
# |jaguar      |32        |
# |jeep        |33        |
# |jetour      |34        |
# |jmc         |35        |
# |kaiyi       |36        |
# |karry       |37        |
# |kia         |38        |
# |land rover  |39        |
# |lexus       |40        |
# |lifan       |41        |
# |mahindra    |42        |
# |maxus       |43        |
# |mazda       |44        |
# |mercedes    |45        |
# |mg          |46        |
# |mini        |47        |
# |mitsubishi  |48        |
# |nissan      |49        |
# |omoda       |50        |
# |opel        |51        |
# |otros       |52        |
# |peugeot     |53        |
# |porsche     |54        |
# |ram         |55        |
# |renault     |56        |
# |seat        |57        |
# |shineray    |58        |
# |skoda       |59        |
# |ssangyong   |60        |
# |subaru      |61        |
# |suzuki      |62        |
# |swm         |63        |
# |tata        |64        |
# |tesla       |65        |
# |toyota      |66        |
# |uaz         |67        |
# |volkswagen  |68        |
# |volvo       |69        |
# +------------+----------+
