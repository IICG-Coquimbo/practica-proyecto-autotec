# %% [markdown]
# # DBSCAN con configuración óptima eps=1.0 y min_samples=3

# %%
# =========================
# LIBRERÍAS
# =========================
from pyspark.ml.feature import VectorAssembler, StandardScaler, PCA

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score

# =========================
# PREPARAR DATOS
# =========================
df_cast = (
    df
    .withColumnRenamed("precio", "precio_num")
    .dropna(subset=["precio_num", "kilometraje", "year"])
)

print("Registros:", df_cast.count())

# =========================
# VECTORIZACIÓN
# =========================
assembler = VectorAssembler(
    inputCols=["precio_num", "kilometraje", "year"],
    outputCol="features"
)

df_vector = assembler.transform(df_cast)

# =========================
# ESTANDARIZACIÓN
# =========================
scaler = StandardScaler(
    inputCol="features",
    outputCol="scaledFeatures"
)

scaler_model = scaler.fit(df_vector)
df_scaled = scaler_model.transform(df_vector)

# =========================
# PCA (REDUCCIÓN A 2 COMPONENTES)
# =========================
pca = PCA(
    k=2,
    inputCol="scaledFeatures",
    outputCol="pcaFeatures"
)

pca_model = pca.fit(df_scaled)
df_pca = pca_model.transform(df_scaled)

pdf_pca = df_pca.select("pcaFeatures", "marca", "precio_num", "kilometraje", "year").toPandas()

X_pca = np.array(
    pdf_pca["pcaFeatures"]
    .apply(lambda x: x.toArray())
    .tolist()
)

print("Dimensión matriz PCA:", X_pca.shape)

# =========================
# DBSCAN SOBRE PCA
# =========================
eps_value = 1.0
min_samples_value = 3

dbscan = DBSCAN(
    eps=eps_value,
    min_samples=min_samples_value
)

clusters = dbscan.fit_predict(X_pca)

pdf_pca["cluster"] = clusters
pdf_pca["PC1"] = X_pca[:, 0]
pdf_pca["PC2"] = X_pca[:, 1]

# =========================
# MÉTRICAS
# =========================
num_clusters = len(set(clusters)) - (1 if -1 in clusters else 0)
num_outliers = list(clusters).count(-1)

print("Clusters detectados:", num_clusters)
print("Outliers detectados:", num_outliers)

if num_clusters > 1:
    silhouette = silhouette_score(X_pca, clusters)
    print("Silhouette Score:", round(silhouette, 3))
else:
    silhouette = None
    print("No es posible calcular Silhouette Score")

# =========================
# VISUALIZACIÓN
# =========================
sns.set_style("whitegrid")

colores = {
    -1: "#FF6B6B",  # rojo suave
     0: "#A8DADC",  # celeste pastel
     1: "#CDB4DB",  # morado pastel
     2: "#95D5B2",
     3: "#FFD6A5",
     4: "#BDE0FE",
     5: "#F4A261",
     6: "#84A59D",
     7: "#F6BD60",
     8: "#6D597A",
     9: "#83C5BE"
}

plt.figure(figsize=(12, 8))

sns.scatterplot(
    data=pdf_pca,
    x="PC1",
    y="PC2",
    hue="cluster",
    palette=colores,
    s=75,
    alpha=0.75,
    edgecolor="black",
    linewidth=0.3
)

# Resaltar ruido
outliers = pdf_pca[pdf_pca["cluster"] == -1]

if len(outliers) > 0:
    plt.scatter(
        outliers["PC1"],
        outliers["PC2"],
        color="#FF6B6B",
        marker="x",
        s=90,
        linewidth=2
    )

plt.title(
    f"Clustering DBSCAN con PCA\n(eps={eps_value}, min_samples={min_samples_value})",
    fontsize=16,
    fontweight="bold"
)

plt.xlabel("Componente Principal 1")
plt.ylabel("Componente Principal 2")

plt.legend(
    title="Cluster",
    bbox_to_anchor=(1.02, 1),
    loc="upper left"
)

plt.tight_layout()
plt.show()

# =========================
# RESUMEN FINAL
# =========================
print("\n==============================")
print(" RESULTADOS DEL CLUSTERING CON PCA ")
print("==============================")
print("Registros analizados:", len(pdf_pca))
print("Clusters encontrados:", num_clusters)
print("Outliers detectados:", num_outliers)

if silhouette is not None:
    print("Silhouette Score:", round(silhouette, 3))

print("==============================")
# Out:
# Registros: 1988
# Dimensión matriz PCA: (1988, 2)
# Clusters detectados: 2
# Outliers detectados: 5
# Silhouette Score: 0.694
# ...
#  RESULTADOS DEL CLUSTERING CON PCA
# ...
# Registros analizados: 1988
# Clusters encontrados: 2
# Outliers detectados: 5
# Silhouette Score: 0.694
# ...

# %% [markdown]
# # Resultados del Clustering con PCA
#
# En el análisis de **1988 vehículos** usando DBSCAN sobre las componentes principales (PC1 y PC2), se obtuvieron los siguientes resultados:
#
# - **Clusters encontrados:** 2
# - **Outliers detectados:** 5
# - **Silhouette Score:** 0.694
#
# ## Interpretación en contexto de autos
# - Los **2 clusters** representan dos grupos principales de autos con características similares en precio, kilometraje y año.
# - Los **5 outliers** corresponden a vehículos con valores atípicos (ej. precios muy altos o kilometrajes extremos) que no encajan en los grupos principales.
# - El **Silhouette Score de 0.694** indica que los autos dentro de cada cluster están bastante bien agrupados y que los clusters están bien separados entre sí. En términos prácticos, significa que la segmentación es **robusta y confiable** para distinguir entre diferentes perfiles de vehículos.

# %% [markdown]
# # DBSCAN con configuración eps=0.8 y min_samples=10

# %%
# =========================
# LIBRERÍAS
# =========================
from pyspark.sql.functions import col
from pyspark.ml.feature import VectorAssembler, StandardScaler, PCA

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score

# =========================
# PREPARAR DATOS
# =========================
df_cast = (
    df
    .withColumnRenamed("precio", "precio_num")
    .dropna(subset=["precio_num", "kilometraje", "year"])
)

print("Registros:", df_cast.count())

# =========================
# VECTORIZACIÓN
# =========================
assembler = VectorAssembler(
    inputCols=["precio_num", "kilometraje", "year"],
    outputCol="features"
)

df_vector = assembler.transform(df_cast)

# =========================
# ESTANDARIZACIÓN
# =========================
scaler = StandardScaler(
    inputCol="features",
    outputCol="scaledFeatures"
)

scaler_model = scaler.fit(df_vector)
df_scaled = scaler_model.transform(df_vector)

# =========================
# PCA
# =========================
pca = PCA(
    k=2,
    inputCol="scaledFeatures",
    outputCol="pcaFeatures"
)

pca_model = pca.fit(df_scaled)
df_pca = pca_model.transform(df_scaled)

print("Registros PCA:", df_pca.count())

# =========================
# EXPORTAR A PANDAS
# =========================
pdf_dbscan = df_pca.select(
    "pcaFeatures",
    "marca",
    "precio_num",
    "kilometraje",
    "year"
).toPandas()

X = np.array(
    pdf_dbscan["pcaFeatures"]
    .apply(lambda x: x.toArray())
    .tolist()
)

print("Dimensión matriz:", X.shape)

# =========================
# DBSCAN
# =========================
eps_value = 0.8
min_samples_value = 10

dbscan = DBSCAN(
    eps=eps_value,
    min_samples=min_samples_value
)

clusters = dbscan.fit_predict(X)

pdf_dbscan["cluster"] = clusters

# =========================
# MÉTRICAS
# =========================
num_clusters = len(set(clusters)) - (1 if -1 in clusters else 0)

num_outliers = list(clusters).count(-1)

print("Clusters detectados:", num_clusters)
print("Outliers:", num_outliers)

if num_clusters > 1:
    silhouette = silhouette_score(X, clusters)
    print("Silhouette Score:", round(silhouette, 3))
else:
    silhouette = None
    print("No es posible calcular Silhouette Score")

# =========================
# PREPARAR COMPONENTES PCA
# =========================
pdf_dbscan["PC1"] = X[:, 0]
pdf_dbscan["PC2"] = X[:, 1]

# =========================
# GRÁFICO
# =========================
plt.figure(figsize=(12,8))

sns.set_style("whitegrid")

sns.scatterplot(
    data=pdf_dbscan,
    x="PC1",
    y="PC2",
    hue="cluster",
    palette="Spectral",
    alpha=0.7,
    s=70
)

outliers = pdf_dbscan[
    pdf_dbscan["cluster"] == -1
]

plt.scatter(
    outliers["PC1"],
    outliers["PC2"],
    marker="x",
    s=60,
    color="red",
    label="Ruido (-1)"
)

plt.title(
    f"DBSCAN - eps={eps_value}, min_samples={min_samples_value}",
    fontsize=15
)

plt.xlabel("Componente Principal 1")
plt.ylabel("Componente Principal 2")

plt.legend(
    bbox_to_anchor=(1.05,1),
    loc="upper left"
)

plt.tight_layout()
plt.show()

# =========================
# RESUMEN FINAL
# =========================
print("\n===== RESULTADOS DBSCAN =====")
print("Registros analizados:", len(pdf_dbscan))
print("Clusters encontrados:", num_clusters)
print("Outliers detectados:", num_outliers)

if silhouette is not None:
    print("Silhouette Score:", round(silhouette, 3))
# Out:
# Registros: 1988
# Registros PCA: 1988
# Dimensión matriz: (1988, 2)
# Clusters detectados: 1
# Outliers: 14
# No es posible calcular Silhouette Score
# ===== RESULTADOS DBSCAN =====
# Registros analizados: 1988
# Clusters encontrados: 1
# Outliers detectados: 14
