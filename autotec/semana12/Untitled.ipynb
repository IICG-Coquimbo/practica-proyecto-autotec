# %%
# ============================================
# GUARDAR DATOS ETIQUETADOS PARA SEMANA 12
# ============================================

import os

# Guardamos el DataFrame con los clusters asignados
df_trabajo["cluster_kmeans"] = clusters_kmeans

# Guardamos como CSV para reutilizar en semana 12
os.makedirs("modelos", exist_ok=True)
df_trabajo.to_csv("modelos/datos_etiquetados_kmeans.csv", index=False)
print("Datos guardados en: modelos/datos_etiquetados_kmeans.csv")
print(f"Total registros: {len(df_trabajo)}")
print(df_trabajo[["marca", "precio", "kilometraje", "year", "cluster_kmeans"]].head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       5 import os
#       7 # Guardamos el DataFrame con los clusters asignados
# ----> 8 df_trabajo["cluster_kmeans"] = clusters_kmeans
#      10 # Guardamos como CSV para reutilizar en semana 12
#      11 os.makedirs("modelos", exist_ok=True)
#
# NameError: name 'clusters_kmeans' is not defined
