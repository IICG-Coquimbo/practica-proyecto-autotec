# %% [markdown]
# El siguiente diccionario de datos describe las variables utilizadas para la construcción del modelo predictivo orientado a estimar el precio de vehículos usados.
#
# Las variables fueron seleccionadas considerando su relevancia para explicar el valor comercial de un vehículo y su disponibilidad dentro de la base de datos AutoTec.

# %%
import pandas as pd

diccionario = pd.DataFrame({
    "Variable": [
        "precio",
        "kilometraje",
        "year",
        "marca",
        "modelo",
        "combustible",
        "ciudad"
    ],
    "Tipo": [
        "Numérica",
        "Numérica",
        "Numérica",
        "Categórica",
        "Categórica",
        "Categórica",
        "Categórica"
    ],
    "Descripción": [
        "Valor comercial del vehículo usado",
        "Cantidad de kilómetros recorridos por el vehículo",
        "Año de fabricación o publicación asociado al vehículo",
        "Marca comercial del vehículo",
        "Modelo específico del vehículo",
        "Tipo de combustible utilizado por el vehículo",
        "Ciudad donde se publica o comercializa el vehículo"
    ],
    "Unidad de medida": [
        "Pesos chilenos (CLP)",
        "Kilómetros (km)",
        "Año",
        "No aplica",
        "No aplica",
        "No aplica",
        "No aplica"
    ],
    "Rol en el modelo": [
        "Variable dependiente Y",
        "Variable predictora",
        "Variable predictora",
        "Variable predictora",
        "Variable predictora",
        "Variable predictora",
        "Variable predictora"
    ]
})

diccionario
# Out:
#       Variable        Tipo                                        Descripción  \
# 0       precio    Numérica                 Valor comercial del vehículo usado
# 1  kilometraje    Numérica  Cantidad de kilómetros recorridos por el vehículo
# 2         year    Numérica  Año de fabricación o publicación asociado al v...
# 3        marca  Categórica                       Marca comercial del vehículo
# 4       modelo  Categórica                     Modelo específico del vehículo
# 5  combustible  Categórica      Tipo de combustible utilizado por el vehículo
# 6       ciudad  Categórica  Ciudad donde se publica o comercializa el vehí...
#
#        Unidad de medida        Rol en el modelo
# 0  Pesos chilenos (CLP)  Variable dependiente Y
# 1       Kilómetros (km)     Variable predictora
# 2                   Año     Variable predictora
# 3             No aplica     Variable predictora
# 4             No aplica     Variable predictora
# 5             No aplica     Variable predictora
# ...

# %% [markdown]
# A partir del análisis realizado, se definió la variable precio como variable dependiente (Y) del modelo predictivo, ya que representa el valor comercial de los vehículos usados y constituye el principal atributo de interés para la estimación de precios dentro del mercado automotriz.
#
# Las variables identificadas fueron kilometraje, año, marca, combustible y ciudad, las cuales entregan información relevante sobre las características técnicas y comerciales de cada vehículo. A partir de los análisis anteriores, se puede observar que variables como el año y el kilometraje influyen en el comportamiento del precio.
#
# Además, la base de datos cuenta con una gran cantidad de registros y una adecuada diversidad de observaciones, lo que permite concluir que existe factibilidad para desarrollar modelos predictivos orientados a la estimación de precios.
#
# Finalmente, el diccionario de datos elaborado proporciona una descripción formal de las variables utilizadas, facilitando la comprensión y correcta interpretación de la información empleada en el proyecto.
