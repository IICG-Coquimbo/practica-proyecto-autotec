# %%
from pyspark.sql import SparkSession
import os

spark = SparkSession.builder.appName("Exportar_Autos").getOrCreate()

# Recuperar el DataFrame limpio desde Semana 9
df_completos = spark.read.parquet("/home/jovyan/work/semanas/Semana 9. EDA/datos_Completos")

# Crear carpeta Semana 15 si no existe
output_dir = "/home/jovyan/work/semanas/Semana 15"
os.makedirs(output_dir, exist_ok=True)

# Exportar a CSV
csv_path = os.path.join(output_dir, "datos_autos_dashboard.csv")
df_completos.toPandas().to_csv(csv_path, index=False)

print(f"✅ Datos exportados listos para Streamlit en: {csv_path}")
# Out:
# ✅ Datos exportados listos para Streamlit en: /home/jovyan/work/semanas/Semana 15/datos_autos_dashboard.csv

# %%
import os
from pyspark.sql import SparkSession

# Crear sesión Spark (si no está activa)
spark = SparkSession.builder.appName("Exportar_Autos").getOrCreate()

# Recuperar el DataFrame limpio desde Semana 9
df_completos = spark.read.parquet("/home/jovyan/work/semanas/Semana 9. EDA/datos_Completos")

# Crear carpeta Semana 15 si no existe
output_dir = "/home/jovyan/work/semanas/Semana 15"
os.makedirs(output_dir, exist_ok=True)

# Exportar a CSV para Streamlit
csv_path = os.path.join(output_dir, "datos_autos_dashboard.csv")
df_completos.toPandas().to_csv(csv_path, index=False)

print(f"✅ Datos exportados listos para Streamlit en: {csv_path}")
# Out:
# ✅ Datos exportados listos para Streamlit en: /home/jovyan/work/semanas/Semana 15/datos_autos_dashboard.csv

# %%
import os

# Verificar que el archivo está en la carpeta
print(os.listdir("/home/jovyan/work/semanas/Semana 15"))
# Out:
# ['datos_autos_dashboard.csv']

# %%
import pandas as pd

df_check = pd.read_csv("/home/jovyan/work/semanas/Semana 15/datos_autos_dashboard.csv")
print(df_check.head())
print("Registros exportados:", len(df_check))
# Out:
#        ciudad combustible kilometraje       marca    modelo    precio  year  \
# 0    La Reina     Bencina   125000 km  Volkswagen     Atlas  23900000  2021
# 1   Cerrillos     Bencina   112000 km       Honda      Wr-v   9280000  2021
# 2  San Felipe     Bencina    94000 km        Ford  Explorer  18500000  2019
# 3       Maipú     Bencina     9000 km   Chevrolet  Suburban  57000000  2024
# 4   Cerrillos     Bencina    20789 km         Kia   Morning   9680000  2023
#
#    precio_num  kilometraje_num    precio_eur
# 0    23900000           125000  24387.755102
# 1     9280000           112000   9469.387755
# 2    18500000            94000  18877.551020
# 3    57000000             9000  58163.265306
# 4     9680000            20789   9877.551020
# Registros exportados: 2560

# %%
import os
print(os.listdir("/home/jovyan/work/semanas/Semana 15"))
# Out:
# ['datos_autos_dashboard.csv']
