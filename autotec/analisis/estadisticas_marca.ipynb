# %%
from pymongo import MongoClient
import pandas as pd

# %%
uri = "mongodb+srv://neiel_cortes:neiel0330@cluster0.eo0kyfv.mongodb.net/"

client = MongoClient(uri)

db = client["proyecto_bigdata"]

collection = db["marca_limpia"]

# %%
data = list(collection.find())

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                         _id                ciudad combustible  \
# 0  69f3e873b71b4c57fe3a5d6d  región metropolitana     bencina
# 1  69f3e873b71b4c57fe3a5d6e                  buin      diesel
# 2  69f3e873b71b4c57fe3a5d72              la reina     bencina
# 3  69f3e873b71b4c57fe3a5d76             cerrillos     bencina
# 4  69f3e873b71b4c57fe3a5d7a            san felipe     bencina
#
#          fecha_captura    grupo kilometraje       marca    modelo    precio  \
# 0  2026-04-30 23:39:11  autotec    35000 km          hs            10970000
# 1  2026-04-30 23:39:11  autotec      180 km      toyota     hilux  12600000
# 2  2026-04-30 23:39:11  autotec   125000 km  volkswagen     atlas  23900000
# 3  2026-04-30 23:39:11  autotec   112000 km       honda      wr-v   9280000
# 4  2026-04-30 23:39:11  autotec    94000 km        ford  explorer  18500000
#
#                                                  url usuario  year  \
# ...

# %%
print(len(df))
# Out:
# 3422

# %%
print(df.isnull().sum())
# Out:
# _id                 0
# ciudad            212
# combustible       212
# fecha_captura       0
# grupo               0
# kilometraje         0
# marca               0
# modelo              0
# precio              0
# url                 0
# usuario             0
# year                0
# marca_limpia        0
# fuente           2316
# dtype: int64

# %%
porcentaje = df["marca_limpia"].value_counts(normalize=True) * 100

print(round(porcentaje, 2))
# Out:
# marca_limpia
# chevrolet          8.47
# ford               7.92
# peugeot            7.45
# nissan             7.16
# chery              5.03
#                    ...
# actyon             0.03
# jim                0.03
# renault-samsung    0.03
# faw                0.03
# infiniti           0.03
# Name: proportion, Length: 101, dtype: float64

# %%
frecuencia = df["marca_limpia"].value_counts()

porcentaje = df["marca_limpia"].value_counts(normalize=True) * 100

# %%
resumen = pd.DataFrame({
    "frecuencia": frecuencia,
    "porcentaje": round(porcentaje, 2)
})

print(resumen.head(20))
# Out:
#               frecuencia  porcentaje
# marca_limpia
# chevrolet            290        8.47
# ford                 271        7.92
# peugeot              255        7.45
# nissan               245        7.16
# chery                172        5.03
# toyota               167        4.88
# kia                  136        3.97
# hyundai              134        3.92
# mg                   114        3.33
# volkswagen           112        3.27
# mazda                 99        2.89
# suzuki                72        2.10
# jeep                  65        1.90
# ssangyong             63        1.84
# subaru                62        1.81
# mitsubishi            61        1.78
# changan               55        1.61
# audi                  55        1.61
# mercedes              55        1.61
# citroen               53        1.55

# %%
premium = [
    "bmw",
    "audi",
    "mercedes",
    "lexus",
    "jaguar",
    "volvo",
    "land rover"
]

df["tipo_marca"] = df["marca_limpia"].apply(
    lambda x: "premium" if x in premium else "generalista"
)

# %%
print(df[["marca_limpia", "tipo_marca"]].head(20))
# Out:
#    marca_limpia   tipo_marca
# 0            hs  generalista
# 1        toyota  generalista
# 2    volkswagen  generalista
# 3         honda  generalista
# 4          ford  generalista
# 5     chevrolet  generalista
# 6           kia  generalista
# 7        nissan  generalista
# 8     chevrolet  generalista
# 9    land rover      premium
# 10       nissan  generalista
# 11        chery  generalista
# 12      changan  generalista
# 13    chevrolet  generalista
# 14     mercedes      premium
# 15       suzuki  generalista
# 16   mitsubishi  generalista
# 17        mazda  generalista
# 18           mg  generalista
# 19    chevrolet  generalista

# %%
print(df["tipo_marca"].value_counts())
# Out:
# tipo_marca
# generalista    3191
# premium         231
# Name: count, dtype: int64

# %%
print("Duplicados:", df.duplicated().sum())
# Out:
# Duplicados: 0

# %%
## Conclusiones

#- Chevrolet, Ford y Peugeot son las marcas con mayor frecuencia.
#- La mayoría de los vehículos corresponden a marcas generalistas.
#- Las marcas premium poseen menor representación dentro del dataset.
#- La variable marca fue limpiada y normalizada correctamente.
#- No se detectaron duplicados relevantes.
