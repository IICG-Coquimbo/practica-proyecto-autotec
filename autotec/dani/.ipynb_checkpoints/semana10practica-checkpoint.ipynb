# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, regexp_extract, when, lit, udf, regexp_replace
from pyspark.sql.types import FloatType, StringType, IntegerType
import re
# Cambiamos .get_session() por .getOrCreate()
spark = SparkSession.builder \
    .appName("EDA_AutoTec_Dani") \
    .config("spark.mongodb.read.connection.uri", "mongodb+srv://neiel_cortes:neiel0330@cluster0.eo0kyfv.mongodb.net/AutoTec_db") \
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:10.1.1") \
    .getOrCreate() # <--- Línea corregida get_session() es solo si ya se ha iniciado una sesión previa

# Carga de datos crudos desde Atlas
df_ = spark.read.format("mongodb") \
    .option("database", "proyecto_bigdata") \
    .option("collection", "lista_autos") \
    .load()

# %%
print(df_.count())
# Out:
# 3627

# %%
df_cleaned = df_.filter(
    (col("_id").isNotNull()) & 
    (col("_id") != "") & 
    (col("_id") != "Sin ID") &
    (col("_id") != "Sin nombre") &
    
    (col("kilometraje").isNotNull()) &
    (col("kilometraje") != "") &
    
    (col("precio").isNotNull()) &
    (col("precio") != "") &
    
    (col("year").isNotNull()) &
    (col("year") != "") &
    
    (col("combustible").isNotNull()) &
    (col("combustible") != "") &
    
    (col("ciudad").isNotNull()) &
    (col("ciudad") != "")
)

df_cleaned.show(10, truncate=False)

print(f"Total de registros después de limpiar los que no tienen id, kilometraje, precio, año, combustible y ciudad: {df_cleaned.count()}")
# Out:
# +------------------------+--------------------+-----------+-------------------+------+-------+-----------+---------+------------------------------------+--------+----------------------------------------------------------------------------------------+-------+----+
# |_id                     |ciudad              |combustible|fecha_captura      |fuente|grupo  |kilometraje|marca    |modelo                              |precio  |url                                                                                     |usuario|year|
# +------------------------+--------------------+-----------+-------------------+------+-------+-----------+---------+------------------------------------+--------+----------------------------------------------------------------------------------------+-------+----+
# |69f3e873b71b4c57fe3a5d66|talca               |bencina    |2026-04-30 23:35:51|NULL  |autotec|15000 km   |chevrolet|traverse                            |44990000|https://www.yapo.cl/autos-usados/chevrolet-traverse-premier-ano-2024/32007441           |dani   |2024|
# |69f3e873b71b4c57fe3a5d67|isla de maipo       |diesel     |2026-04-30 23:37:48|NULL  |autotec|239000 km  |maxus    |v80                                 |6950000 |https://www.yapo.cl/autos-usados/maxus-v80-2016-furgon-liquido-por-renovacion/31941720  |dani   |2016|
# |69f3e873b71b4c57fe3a5d68|recoleta            |diesel     |2026-04-30 23:35:10|NULL  |autotec|155000 km  |peugeot  |landtrek                            |12990000|https://www.yapo.cl/autos-usados/peugeot-landtrek-4x4-1-9-ano-2022/32292394             |dani   |2022|
# |69f3e873b71b4c57fe3a5d69|valdivia            |bencina    |2026-04-30 23:39:46|NULL  |autotec|49800 km   |chery    |tiggo 8                             |12790000|https://www.yapo.cl/autos-usados/chery-tiggo-8/32284974                                 |dani   |2023|
# |69f3e873b71b4c57fe3a5d6a|providencia         |bencina    |2026-04-30 23:37:11|NULL  |autotec|53000 km   |jeep     |grand cherokee 5.7 overland 4wd auto|27480000|https://www.yapo.cl/autos-usados/2019-jeep-grand-cherokee-5-7-overland-4wd-auto/32255858|dani   |2019|
# |69f3e873b71b4c57fe3a5d6b|concón              |bencina    |2026-04-30 23:38:36|NULL  |autotec|89000 km   |dodge    |journey 2.4                         |12290000|https://www.yapo.cl/autos-usados/2019-dodge-journey/32353370                            |dani   |2019|
# |69f3e873b71b4c57fe3a5d6c|región metropolitana|bencina    |2026-04-30 23:36:34|NULL  |autotec|14594 km   |peugeot  |208                                 |9890000 |https://www.yapo.cl/autos-usados/peugeot-208-2023/31998571                              |dani   |2023|
# |69f3e873b71b4c57fe3a5d6d|región metropolitana|bencina    |2026-04-30 23:39:11|NULL  |autotec|35000 km   |hs       |                                    |10970000|https://www.yapo.cl/autos-usados/mg-hs-1-5t-dct-dlx-2023/32047868                       |dani   |2023|
# |69f3e873b71b4c57fe3a5d6e|buin                |diesel     |2026-04-30 23:39:11|NULL  |autotec|180 km     |toyota   |hilux                               |12600000|https://www.yapo.cl/autos-usados/toyota-hilux-4x4-sr/32168459                           |dani   |2018|
# |69f3e873b71b4c57fe3a5d6f|macul               |diesel     |2026-04-30 23:36:34|NULL  |autotec|1111111 km |dongfeng |df                                  |15900000|https://www.yapo.cl/autos-usados/se-vende-camion-dongfeng-2014/32261160                 |dani   |2014|
# +------------------------+--------------------+-----------+-------------------+------+-------+-----------+---------+------------------------------------+--------+----------------------------------------------------------------------------------------+-------+----+
# only showing top 10 rows
#
# Total de registros después de limpiar los que no tienen id, kilometraje, precio, año, combustible y ciudad: 3256

# %%
def normalizar_float(valor):
    if not valor:
        return None
    try:
        return float(valor.replace(",", "."))
    except:
        return None

normalizar_udf = udf(normalizar_float, FloatType())

df_cleaned = df_cleaned.withColumn(
    "kilometraje", 
    normalizar_udf(col("kilometraje"))
)

df_cleaned = df_cleaned.withColumn(
    "year", 
    normalizar_udf(col("year"))
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_normalized = df_cleaned.withColumn(
#       2     "kilometraje_clean",
#       3     regexp_replace(col("kilometraje").cast(StringType()), r'[^\d,.]', "")
#       4 ).withColumn(
#       5     "kilometraje_clean",
#       6     regexp_replace(col("kilometraje_clean"), ",", ".")
#       7 ).withColumn(
#       8     "year_clean",
#       9     regexp_replace(col("year").cast(StringType()), r'[^\d,.]', "")
#      10 ).withColumn(
#      11     "year_clean",
#      12     regexp_replace(col("year_clean"), ",", ".")
#      13 ).withColumn(
#      14     "precio_clean",
#      15     regexp_replace(col("precio").cast(StringType()), r'[^\d,.]', "")
#      16 ).withColumn(
#      17     "precio_clean",
#      18     regexp_replace(col("precio_clean"), ",", ".")
#      19 )
#
# NameError: name 'df_cleaned' is not defined

# %%
df_normalized = df_cleaned.withColumn(
    "kilometraje_clean", 
    regexp_replace(col("kilometraje"), r'[^\d,.]', "")
).withColumn(
    "kilometraje_clean", 
    regexp_replace(col("kilometraje_clean"), ",", ".")
).withColumn(
    "year_clean", 
    regexp_replace(col("year"), r'[^\d,.]', "")
).withColumn(
    "year_clean", 
    regexp_replace(col("year_clean"), ",", ".")
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_normalized = df_cleaned.withColumn(
#       2     "kilometraje_clean",
#       3     regexp_replace(col("kilometraje"), r'[^\d,.]', "")
#       4 ).withColumn(
#       5     "kilometraje_clean",
#       6     regexp_replace(col("kilometraje_clean"), ",", ".")
#       7 ).withColumn(
#       8     "year_clean",
#       9     regexp_replace(col("year"), r'[^\d,.]', "")
#      10 ).withColumn(
#      11     "year_clean",
#      12     regexp_replace(col("year_clean"), ",", ".")
#      13 )
#
# NameError: name 'df_cleaned' is not defined

# %%
# 2. Casteo de Variables (Normalización de Tipos)
df_final = df_normalized.select(
    col("marca"),
    col("modelo"),
    col("url"),

    # Precio a Float
    col("precio_clean").cast(FloatType()).alias("precio"),

    # Kilometraje a Float
    col("kilometraje_clean").cast(FloatType()).alias("kilometraje"),

    # Año a Integer
    col("year_clean").cast(IntegerType()).alias("year")
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # 2. Casteo de Variables (Normalización de Tipos)
# ----> 2 df_final = df_normalized.select(
#       3     col("sku_id"),
#       4     col("tienda"),
#       5     col("marca"),
#       6     col("formato_raw"),
#       7     col("kilometraje_clean").cast(FloatType()).alias("kilometraje"),
#       8     col("year_clean").cast(IntegerType()).alias("year")
#       9 )
#
# NameError: name 'df_normalized' is not defined

# %%
print("Previsualización de Datos Normalizados (Tipos Correctos):")

df_final.select(
    "sku_id",
    "kilometraje",
    "year"
).show(10, truncate=False)

# --- VERIFICACIÓN DE ESQUEMA ---
df_final.printSchema()
# Out:
# Previsualización de Datos Normalizados (Tipos Correctos):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 print("Previsualización de Datos Normalizados (Tipos Correctos):")
# ----> 3 df_final.select(
#       4     "sku_id",
#       5     "kilometraje",
#       6     "year"
#       7 ).show(10, truncate=False)
#       9 # --- VERIFICACIÓN DE ESQUEMA ---
#      10 df_final.printSchema()
#
# NameError: name 'df_final' is not defined
